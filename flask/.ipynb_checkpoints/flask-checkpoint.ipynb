# %% [markdown]
# ## Structure of URL

# %% [markdown]
# ## About flask framework

# %%
## Building a flask a

# %%
file = open("sample.txt", "wt")

# %%
content = "Hello world"

# %%
for i in range(10000):
    file.write(content)

# %%
from flask import Flask, request

# %%
d = {
    "rahul": "M hoon batman ka robin",
    "kaam" : "am the sidekick"
}

# %%
app = Flask("Hello")

# %%
@app.route("/")
def index():
    return "Hello meri phli web app or ye index page h"

@app.route("/search/")

def search():
    name = request.args.get("name")
    last = request.args.get("last")
    return "hello i am {} and {} ".format(name,last, d["rahul"])

# %%
app.run()
# Out:
#  * Serving Flask app "Hello" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [04/Apr/2020 11:03:58] "GET /search/ HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2020 11:04:13] "GET /search/?ame=Rahul&last=Rahuk HTTP/1.1" 200 -

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://wallpaperaccess.com/iron-man"

# %%
data = requests.get(url)

# %%
soup = BeautifulSoup(data.text)

# %%
soup.find("data-id")
