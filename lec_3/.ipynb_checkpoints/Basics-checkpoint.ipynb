# %% [markdown]
# [Link Text](linnk)
# - List
# - **Bold**
# - *italic*
# - <u>underline</u>
#     - bullet
# - PDF

# %% [markdown]
# ##                           BASICS
# ## Let's write our first "Hello World" program
# - Run on interactive shell/VM
# - Run as python script

# %%
print("Hello World")
# Out:
# Hello World

# %%
## In python we can directly print any data without defining it prior

# %%
print("Hello", "World", "we", "are", "Indians")
# Out:
# Hello World we are Indians

# %%
## This print function is printing it's content line by line.

print("Hello"), print("world"), print("This is")
print("Python")
# Out:
# Hello
# world
# This is
# Python

# %% [markdown]
# ## Putting Comments
# - It tell's you about the code in brief
# - Multiline comment
# - Shortcut for commenting whole code

# %%
## for windows ctrl + /
## for mac cmd + /

# %%
## Hello everyone!! This is a comment

# %%
"""This 
is 
a 
string"""
# Out:
# 'This \nis \na \nstring'

# %%
a = """This 
is 
a 
string"""

# %%
type(a)
# Out:
# str

# %%
a = ## this is comment and will show error
# Out:
#   File "<ipython-input-1-3928bca0f090>", line 1
#     a = ## this is comment and will show error
#                                               ^
# SyntaxError: invalid syntax

# %%
a = "## Now this is string"

# %%
a
# Out:
# '## Now this is string'

# %% [markdown]
# ## Basic Data types in Python
# - Integers
# - Bool
# - Float
# - Complex
#
# Check ***Data type***
#
# Reference and Memory address

# %%
(0 + 0j) == False
# Out:
# True

# %%
## float is int*10(raise to the power something -ve) 
# Actual representation in form of power and mantisa

# %%
# Integers

# %%
z = 2
print(z)
type(z)
# Out:
# 2
# int

# %%
z = -2
type(z)
# Out:
# int

# %%
## int can also be defined in binary with 0b as prefix, ex - 0b10=2, 
## with octo as 0o as prefix ex - 0o10 = 8
## Or hexadecimal as 0x prefix, ex - 0x10 = 16

# %%
print(0b10)
print(0o10)
print(0x10)
# Out:
# 2
# 8
# 16

# %%
int("1000", 2)
# Out:
# 8

# %%
# Float

# %%
## They are numbers with decimals

f = 1.0
type(f)
# Out:
# float

# %%
b = i/10
print(b)
type(b)
# Out:
# 0.1
# float

# %%
# int/int = float, but float*int = int

c = f*10
print(c)
type(c)
# Out:
# 10.0
# float

# %%
## In python 2.7 '/' means floor division 
# In python 3 '/' means simple division and '//' floor division

# %%
f = -2.09878875678
type(c)
# Out:
# float

# %%
a = 323.3434345567865487654578076546568079666887965
b = 323.3434345567865487654578076546568079666887965

# %%
## Another way of writing a float value, in expon form of 10.

a = 4e3
print(a)
# Out:
# 4000.0

# %%
## python automatically displays the value into most readable form.

print(1.23e-3)
print(1.34e-34)
# Out:
# 0.00123
# 1.34e-34

# %%
## infinity

print(float("inf"))
print(float("-inf"))
# Out:
# inf
# -inf

# %%
## Not a number

float("nan")
# Out:
# nan

# %%
# Variable, reference and memory object

a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
print(id(a))
print(id(b))
# Out:
# 1481387862416
# 1481387862392

# %%
a = 34
b = 34
print(id(a))
print(id(b))
print(a == b)
a is b
# Out:
# 140707256776560
# 140707256776560
# True
# True

# %%
# Strings

# %%
s = "Coding Blocks"
print(s)
type(s)
# Out:
# Coding Blocks
# str

# %%
s1 = 'This is another string'
print(s1)
type(s1)
# Out:
# This is another string
# str

# %%
s2 = 'It's not a string'
# Out:
#   File "<ipython-input-65-309279af6c91>", line 1
#     s2 = 'It's not a string'
#              ^
# SyntaxError: invalid syntax

# %%
s3 = "But it's a string"
print(s3)
type(s3)
# Out:
# But it's a string
# str

# %%
s4 = 'you said "This is a string"'
print(s4)
type(s4)
# Out:
# you said "This is a string"
# str

# %%
# Complex

# %%
c = 3j
print(c)
type(c)
# Out:
# 3j
# complex

# %%
c1 = 1 + 5j
print(c1)
type(c1)
# Out:
# (1+5j)
# complex

# %%
## As whole it is imaginary but it has some imag component and some real component.

# %%
c1.real
# Out:
# 1.0

# %%
c1.imag
# Out:
# 5.0

# %%
print(c1.real)
# Out:
# 1.0

# %% [markdown]
# ## Variables
# It's a type of identifier
# Rules for naming identifiers
# - Name must start from Alphabet(small or caps) or underscore(_)
# - They are case sensitive. It can differentiate between small and CAPS.

# %%
__ = "rahul"
print(__)
# Out:
# rahul

# %%
a = 10
b = 3

# %%
rahul = "Rahul"
print(rahul)
print("rahul")
# Out:
# Rahul
# rahul

# %%
c = 3

# %%
a2 = 22
print(a2)
# Out:
# 22

# %%
## Size of a int can be as large as the size of the memory of the system i.e RAM.

# %% [markdown]
# ## Typecasting

# %% [markdown]
# ## About print function
# - format method
# - sep method
# - end method

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello", "World")
# Out:
# Hello World

# %%
## sep is used by print function to give separation between two print statement.
## By default it is ' ' space

# %%
print("Hello", "World", sep='\n')
# Out:
# Hello
# World

# %%
print("Hello", "World", sep=',')
# Out:
# Hello,World

# %%
print("Hello", "World", sep='","')
# Out:
# Hello","World

# %%
## end operator specifies how a print statement ends after it's execution
## \n makes the pointer to point at next line

# %%
print("Hello", "World", end='')
print("!!")
# Out:
# Hello World!!

# %%
print()

# %% [markdown]
# ## Input function
# - It takes input from user i.e us
# - Typecasting of input function

# %%
## when can also give a string inside input statement but it's not recommended.

a = input()
# Out:
#  2

# %%
type(a)
# Out:
# str

# %%
## type of output from a input function is always a string
## Hence typecasting is used

# %%
a1 = int(input())
# Out:
#  3

# %%
type(a1)
# Out:
# int

# %%
b = float(input())
# Out:
#  1

# %%
type(b)
# Out:
# float

# %%
## After typecasting the value of int typecasted should be integer only

b1 = int(input())
# Out:
#  1.3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6597531ebbfc> in <module>
#       1 ## After typecasting the value of int typecasted should be integer only
#       2
# ----> 3 b1 = int(input())
#
# ValueError: invalid literal for int() with base 10: '1.3'

# %%
b2 = int(input())
# Out:
#  str
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-409c08627aa4> in <module>
# ----> 1 b2 = int(input())
#
# ValueError: invalid literal for int() with base 10: 'str'

# %%
## In float the input value should either be int or a float value

c = float(input())
# Out:
#  sd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f7c2daecf46c> in <module>
#       1 ## In float the input value should either be int or a float value
#       2
# ----> 3 c = float(input())
#
# ValueError: could not convert string to float: 'sd'

# %% [markdown]
# ## Indentation
# - Game of whitespaces

# %%
## tab, and spaces
## ctrl + tab for indenting multiline code. shift + tab for dedenting selected code/multiline.
## parent and child statements
## generally 1 tab = 4 spaces
## For each level we use 4 spaces as standard in our community, even python develop say so.
## Never mix spaces and tabs.

# %%
sum(4,5)
# Out:
# 9

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
## Finally a poem on Python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
